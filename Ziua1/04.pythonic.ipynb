# %%
pare = []

o_lista = [23, 34, 42, 321, 321, 312, 553, 2123, 335]

for i in o_lista:
    if i % 2 == 0:
        pare.append(i)

pare
# Out:
# [34, 42, 312]

# %% [markdown]
# # List comprehention

# %%
o_lista = [23, 34, 42, 321, 321, 312, 553, 2123, 335]
pare = [ i for i in o_lista if i % 2 == 0]
pare
# Out:
# [34, 42, 312]
