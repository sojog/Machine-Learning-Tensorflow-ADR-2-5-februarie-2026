# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Source : https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('Boston_data.csv', header=None, delimiter=r"\s+", names=column_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
standard_scaler = StandardScaler()
standard_scaler
# Out:
# StandardScaler()

# %%
scaled_np_array = standard_scaler.fit_transform(df)
scaled_np_array
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ...,  0.44105193,
#         -1.0755623 ,  0.15968566],
#        [-0.41733926, -0.48772236, -0.59338101, ...,  0.44105193,
#         -0.49243937, -0.10152429],
#        [-0.41734159, -0.48772236, -0.59338101, ...,  0.39642699,
#         -1.2087274 ,  1.32424667],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  0.44105193,
#         -0.98304761,  0.14880191],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  0.4032249 ,
#         -0.86530163, -0.0579893 ],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  0.44105193,
#         -0.66905833, -1.15724782]], shape=(506, 14))

# %%
scaled_df = pd.DataFrame(scaled_np_array, columns=column_names)
scaled_df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# ...

# %%
initial_df = df
df = scaled_df

# %%
df.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.describe()
# Out:
#                CRIM            ZN         INDUS          CHAS           NOX  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean  -1.123388e-16  7.898820e-17  2.106352e-16 -3.510587e-17 -1.965929e-16
# std    1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00
# min   -4.197819e-01 -4.877224e-01 -1.557842e+00 -2.725986e-01 -1.465882e+00
# 25%   -4.109696e-01 -4.877224e-01 -8.676906e-01 -2.725986e-01 -9.130288e-01
# 50%   -3.906665e-01 -4.877224e-01 -2.110985e-01 -2.725986e-01 -1.442174e-01
# 75%    7.396560e-03  4.877224e-02  1.015999e+00 -2.725986e-01  5.986790e-01
# max    9.933931e+00  3.804234e+00  2.422565e+00  3.668398e+00  2.732346e+00
#
#                  RM           AGE           DIS           RAD         TAX  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  506.000000
# mean  -1.088282e-16 -1.474446e-16 -8.425408e-17 -1.123388e-16    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.head(2)
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1 -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0  0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1  0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439 -0.101524

# %%
df.tail(2)
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 504 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.669058 -1.157248

# %%
y = df [['MEDV']]
y
# Out:
#          MEDV
# 0    0.159686
# 1   -0.101524
# 2    1.324247
# 3    1.182758
# 4    1.487503
# ..        ...
# 501 -0.014454
# 502 -0.210362
# 503  0.148802
# 504 -0.057989
# 505 -1.157248
#
# [506 rows x 1 columns]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df [ ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
x
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
x = df.drop('MEDV', axis=1)
x
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prezis = model.predict(x_test)
y_prezis
# Out:
# array([[ 0.37511193],
#        [ 1.28391246],
#        [-1.05160763],
#        [-1.7690754 ],
#        [-0.09602201],
#        [ 0.05747175],
#        [ 0.39450477],
#        [-0.79612231],
#        [-0.43138689],
#        [-0.92525383],
#        [-0.29537321],
#        [ 0.50274566],
#        [ 0.82394696],
#        [-0.33187349],
#        [-0.85329767],
#        [-0.41024394],
#        [ 0.63740392],
#        [-0.5177051 ],
#        [ 0.2649106 ],
#        [-1.41599751],
#        [ 0.2510804 ],
#        [-0.22782113],
#        [ 0.02202116],
#        [ 0.02847514],
#        [-0.32321735],
#        [-0.04334221],
#        [-0.76528641],
#        [-0.20573862],
#        [ 1.4956042 ],
#        [ 0.10659341],
#        [-0.35514778],
#        [ 0.23033208],
#        [ 1.12707042],
#        [-0.72931601],
#        [ 0.12815324],
#        [-0.99947852],
#        [ 1.30841155],
#        [-1.51357916],
#        [ 0.18209348],
#        [ 0.47133942],
#        [ 1.51858884],
# ...

# %%
y_test
# Out:
#          MEDV
# 82   0.246756
# 98   2.314668
# 435 -0.993992
# 398 -1.908226
# 330 -0.297432
# ..        ...
# 412 -0.504223
# 352 -0.428037
# 17  -0.547758
# 291  1.607224
# 363 -0.623944
#
# [102 rows x 1 columns]

# %% [markdown]
# # Comparatie y_prezis (x_test) vs y_test

# %%
comp_df = pd.DataFrame({ "prezis": y_prezis.flatten(),
"real": y_test["MEDV"] })
comp_df
# Out:
#        prezis      real
# 82   0.375112  0.246756
# 98   1.283912  2.314668
# 435 -1.051608 -0.993992
# 398 -1.769075 -1.908226
# 330 -0.096022 -0.297432
# ..        ...       ...
# 412 -2.237528 -0.504223
# 352 -0.575411 -0.428037
# 17  -0.622985 -0.547758
# 291  1.231857  1.607224
# 363 -0.224834 -0.623944
#
# [102 rows x 2 columns]

# %%
plt.scatter( y_test["MEDV"] ,  y_prezis.flatten())
plt.xlabel("Y real")
plt.ylabel("Y prezis")
# Out:
# Text(0, 0.5, 'Y prezis')

# %%
comp_df["score"] = (comp_df["prezis"]- comp_df["real"]) ** 2
comp_df
# Out:
#        prezis      real     score
# 82   0.375112  0.246756  0.016475
# 98   1.283912  2.314668  1.062456
# 435 -1.051608 -0.993992  0.003320
# 398 -1.769075 -1.908226  0.019363
# 330 -0.096022 -0.297432  0.040566
# ..        ...       ...       ...
# 412 -2.237528 -0.504223  3.004346
# 352 -0.575411 -0.428037  0.021719
# 17  -0.622985 -0.547758  0.005659
# 291  1.231857  1.607224  0.140901
# 363 -0.224834 -0.623944  0.159289
#
# [102 rows x 3 columns]

# %%
comp_df["score"].sum()
# Out:
# np.float64(25.94356882568445)

# %%
np.sqrt(comp_df["score"].sum())
# Out:
# np.float64(5.093482975890314)

# %%
model.score(x_test, y_test)
# Out:
# 0.7695834125160264

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.7818137663121685

# %%
knn_scores = {}

for k in range(2, 11):
    knn_model = KNeighborsRegressor(n_neighbors=k)
    knn_model.fit(x_train, y_train)
    score = knn_model.score(x_test, y_test)
    knn_scores[f"{k}"] = score

# %%
knn_scores
# Out:
# {'2': 0.881916137425789,
#  '3': 0.8592812184558951,
#  '4': 0.8259865973605953,
#  '5': 0.7818137663121685,
#  '6': 0.7838558028569544,
#  '7': 0.7941397500926133,
#  '8': 0.7910504102806172,
#  '9': 0.7893459511748954,
#  '10': 0.7936309267590654}

# %%
np.array(list(knn_scores.values())).max()
# Out:
# np.float64(0.881916137425789)

# %%
np.array(list(knn_scores.values())).argmax()
# Out:
# np.int64(0)
